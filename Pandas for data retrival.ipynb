# %%
import pandas as pd

# %%
df = pd.read_csv("gps_track.txt", )

# %%
df.head()
# Out:
#     type       ident        lat       long        y_proj        x_proj  \
# 0  TRACK  ACTIVE LOG  40.789661 -77.859485  4.627252e+06  1.779451e+06
# 1  TRACK  ACTIVE LOG  40.789640 -77.859550  4.627248e+06  1.779446e+06
# 2  TRACK  ACTIVE LOG  40.789618 -77.859571  4.627246e+06  1.779445e+06
# 3  TRACK  ACTIVE LOG  40.789533 -77.859657  4.627235e+06  1.779439e+06
# 4  TRACK  ACTIVE LOG  40.789576 -77.859721  4.627239e+06  1.779433e+06
#
#    new_seg  display  color    altitude  depth  temp                 time  \
# 0     True    False    255  358.228394      0     0  2008/06/11-14:08:30
# 1    False    False    255  358.228394      0     0  2008/06/11-14:09:43
# 2    False    False    255  357.747803      0     0  2008/06/11-14:09:44
# 3    False    False    255  353.421875      0     0  2008/06/11-14:10:18
# 4    False    False    255  356.786377      0     0  2008/06/11-14:11:57
#
#            model filename                ltime
# 0  eTrex Venture           2008/06/11 09:08:30
# ...

# %%
df.columns
# Out:
# Index(['type', 'ident', 'lat', 'long', 'y_proj', 'x_proj', 'new_seg',
#        'display', 'color', 'altitude', 'depth', 'temp', 'time', 'model',
#        'filename', 'ltime'],
#       dtype='object')

# %%
new_df=df[["lat","long","altitude"]].copy()

# %%
new_df.head()
# Out:
#          lat       long    altitude
# 0  40.789661 -77.859485  358.228394
# 1  40.789640 -77.859550  358.228394
# 2  40.789618 -77.859571  357.747803
# 3  40.789533 -77.859657  353.421875
# 4  40.789576 -77.859721  356.786377

# %%
new_df.to_csv("lat_lon_Alt.csv")

# %%
data = pd.read_csv("lat_lon_Alt.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        lat       long    altitude
# 0           0  40.789661 -77.859485  358.228394
# 1           1  40.789640 -77.859550  358.228394
# 2           2  40.789618 -77.859571  357.747803
# 3           3  40.789533 -77.859657  353.421875
# 4           4  40.789576 -77.859721  356.786377
